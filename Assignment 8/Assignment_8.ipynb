# %% [markdown]
# Name : Nisha Yuvraj Pragane | DIV:SEDA | Roll no :13 | PRN : 1252090013 | BATCH :B1
# Assignment 8 : Apply appropriate ML algorithm on a dataset collected in a cosmetics shop showing details of customers to predict customer response for special offer. Create confusion matrix based on above data and find
# Accuracy ,Precision,Recall,F-1 score.

# %%
import pandas as pd
import numpy as np
data = {
    "Age": [19,22,25,31,45,52,23,40,60,48,33,27,21,55,36,29,42],
    "Gender": ["F","F","M","F","F","M","F","M","F","M","F","M","F","F","M","F","M"],
    "Income": [15000,18000,35000,42000,52000,61000,20000,45000,70000,58000,40000,30000,17000,65000,48000,29000,55000],
    "Purchase_History": [1,0,2,3,4,5,0,2,6,4,3,2,1,5,3,1,4],
    "Visited_Website": [5,3,8,10,12,15,4,7,20,14,9,6,2,18,11,5,13],
    "Response": ["No","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","Yes","Yes","No","Yes","Yes","No","Yes"]
}
df = pd.DataFrame(data)
df
# Out:
#     Age Gender  Income  Purchase_History  Visited_Website Response
# 0    19      F   15000                 1                5       No
# 1    22      F   18000                 0                3       No
# 2    25      M   35000                 2                8      Yes
# 3    31      F   42000                 3               10      Yes
# 4    45      F   52000                 4               12      Yes
# 5    52      M   61000                 5               15      Yes
# 6    23      F   20000                 0                4       No
# 7    40      M   45000                 2                7      Yes
# 8    60      F   70000                 6               20      Yes
# 9    48      M   58000                 4               14      Yes
# 10   33      F   40000                 3                9      Yes
# 11   27      M   30000                 2                6      Yes
# 12   21      F   17000                 1                2       No
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Data Preprocessing

# %%
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['Response'] = le.fit_transform(df['Response'])
df
# Out:
#     Age  Gender  Income  Purchase_History  Visited_Website  Response
# 0    19       0   15000                 1                5         0
# 1    22       0   18000                 0                3         0
# 2    25       1   35000                 2                8         1
# 3    31       0   42000                 3               10         1
# 4    45       0   52000                 4               12         1
# 5    52       1   61000                 5               15         1
# 6    23       0   20000                 0                4         0
# 7    40       1   45000                 2                7         1
# 8    60       0   70000                 6               20         1
# 9    48       1   58000                 4               14         1
# 10   33       0   40000                 3                9         1
# 11   27       1   30000                 2                6         1
# 12   21       0   17000                 1                2         0
# ...

# %% [markdown]
# Split Features and Target

# %%
X = df.drop("Response", axis=1)
y = df["Response"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Apply ML Algorithm

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
#  [[3 0]
#  [0 3]]

# %% [markdown]
# Performance Metrics

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1 Score :", f1)
# Out:
# Accuracy : 1.0
# Precision: 1.0
# Recall   : 1.0
# F1 Score : 1.0
